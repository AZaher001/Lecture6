# %%
import random
import os

# %%
os.chdir('C:\\Users\\Computec\\Documents')

# %%
def name_dir(space):
    xspace = os.listdir(space)
    return xspace

# %%
data_name = name_dir('universe')
print(data_name)

# %%
x = 1
for file_name in data_name:
    ran_choice = random.choice(data_name) 
    split_name = ran_choice.split('_')[0]
    print(split_name)
    for i in range(len(data_name)):
        old_name = 'cover' + str(i)+'.png'
    new_name = 'amr'  + str(x)+'.png'
    x = x + 1
    os.rename(old_name,new_name)
