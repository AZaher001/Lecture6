# %%
from my_packages.Transformers import StringTransformer as st

# %%
dir(st)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'fcapitalize',
#  'freverse']

# %%
st.freverse('Ahmed')
# Out:
# 'demhA'

# %%
st.fcapitalize('amr')
# Out:
# 'Amr'

# %%
from my_packages.Operations.math import math

# %%
math()
# Out:
# How many number you need in list started from 1 : 100
# The Avrage =  50.5
